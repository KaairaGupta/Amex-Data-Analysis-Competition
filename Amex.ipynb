# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics

# %%
train_dataset=pd.read_csv('development_dataset.csv')
test_dataset=pd.read_csv('leaderboard_dataset.csv')

# %%
train_dataset.loc[:,'VAR14'][train_dataset.loc[:,'VAR14'].isin(['.'])] = np.NaN
train_dataset['VAR14'] = train_dataset['VAR14'].apply(pd.to_numeric)
test_dataset.loc[:,'VAR14'][test_dataset.loc[:,'VAR14'].isin(['.'])] = np.NaN
test_dataset['VAR14'] = test_dataset['VAR14'].apply(pd.to_numeric)
test_dataset.head()
# Out:
# /home/kaaira/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/kaaira/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    VAR1        VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0     1  878.823529  0.833333  821.428571  620.835806  5.181818  0.833974
# 1     2  891.764706  0.138889  357.142857  614.092215  3.909091  0.595187
# ...

# %%
train_dataset_1=train_dataset.drop(['VAR17','VAR1','VAR21'], axis=1)
test_dataset_1=test_dataset.drop(['VAR17','VAR1'], axis=1)
train_dataset_1=train_dataset_1.fillna(train_dataset.mean())
test_dataset_1=test_dataset_1.fillna(test_dataset.mean())
train_dataset_1.head()
# Out:
#          VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0  828.235294  0.138889  321.428571  625.911006  1.818182  1.081550
# 1  911.764706  0.027778  248.076201  611.574748  8.181818  1.344479
# 2  962.352941  0.833333   35.714286  615.825381  8.181818  0.720796
# 3  892.941177  1.119596  248.076201  638.076431  9.090909  0.820218
# 4  914.117647  0.083333  248.076201  626.514988  5.181818  1.372928
#
#          VAR8       VAR9      VAR10     VAR11       VAR12      VAR13  \
# 0  198.113469  53.988554  58.632548  0.279273  100.083403   1.000000
# 1  198.600020  22.086661  56.497320  5.429062   15.012510  11.679589
# 2  197.267767  53.988554  58.632548  0.453212  210.175146  10.000000
# 3  197.355744   4.363431  58.632548  5.429062  117.283667  11.679589
# 4  198.790477  85.938202  58.632548  5.429062  210.175146  11.679589
#
#       VAR14      VAR15     VAR16  VAR18  VAR19       VAR20
# 0  1.000000   1.000000  1.540594      1      0  100.104991
# ...

# %%
normalized_train=(train_dataset_1-train_dataset_1.mean())/train_dataset_1.std()
normalized_test=(test_dataset_1-test_dataset_1.mean())/test_dataset_1.std()
normalized_train.to_csv('normalized_train.csv', index=False)
normalized_test.to_csv('normalized_test.csv', index=False)

# %%
normalized_train.head()
# Out:
#        VAR2          VAR3          VAR4      VAR5      VAR6      VAR7  \
# 0 -1.800864 -8.128404e-02  3.824356e-01 -0.183405 -0.488353 -0.110026
# 1 -0.113657 -9.049328e-02  3.556359e-14 -0.647920 -0.257672 -0.080317
# 2  0.908172 -2.372632e-02 -1.107187e+00 -0.510193 -0.257672 -0.150788
# 3 -0.493873  2.981408e-15  3.556359e-14  0.210773 -0.224717 -0.139554
# 4 -0.066130 -8.588866e-02  3.556359e-14 -0.163835 -0.366421 -0.077102
#
#        VAR8          VAR9         VAR10         VAR11         VAR12  \
# 0 -0.169948 -1.340720e-13  3.343882e-01 -5.107948e-01 -1.715188e-01
# 1 -0.126283 -5.158146e-01  2.804126e-13  3.611945e-14 -1.019835e+00
# 2 -0.245845 -1.340720e-13  3.343882e-01 -4.935422e-01  9.263017e-01
# 3 -0.237949 -8.023775e-01  3.343882e-01  3.611945e-14 -2.085953e-13
# 4 -0.109191  5.165867e-01  3.343882e-01  3.611945e-14  9.263017e-01
#
#           VAR13         VAR14         VAR15     VAR16     VAR18     VAR19  \
# ...

# %%
X=normalized_train.values
X_test=normalized_test.values

y=train_dataset.iloc[:,20].values
print(X.shape)
# Out:
# (34000, 18)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X,y)
y_pred_lr = clf.predict(X_test)
print(y_pred_lr)
# Out:
# /home/kaaira/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/kaaira/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ['Low' 'Medium' 'Medium' ... 'Medium' 'Medium' 'Medium']

# %%
type(y_pred_lr)
# Out:
# numpy.ndarray

# %%
pd.DataFrame(y_pred_lr).to_csv("Team-rocket_IITRoorkee_5.csv")

# %%
# Out:
#   File "<ipython-input-57-d6ba7d931720>", line 7
#     delete row[]
#              ^
# SyntaxError: invalid syntax
